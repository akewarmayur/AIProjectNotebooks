# %%
# %%capture
# !pip install git+https://github.com/openai/CLIP.git
# !pip install deepface
# !pip install face_recognition

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !ls -la "/content/gdrive/MyDrive/"
# Out:
# total 431354
# -rw------- 1 root root  40115107 May 24  2021  3.mp4
# drwx------ 2 root root      4096 Sep 23  2021  clip_test_video
# drwx------ 9 root root      4096 May 29 08:29  cluster_faces
# -rw------- 1 root root 390881531 Jul 14  2021  Code.zip
# drwx------ 2 root root      4096 Apr 15  2021 'Colab Notebooks'
# drwx------ 2 root root      4096 Mar 13  2020  darknet
# drwx------ 2 root root      4096 Oct 15  2020 'Deep Learning'
# drwx------ 2 root root      4096 Apr 21  2021  demo
# drwx------ 2 root root      4096 Dec 14 11:52  fk
# drwx------ 2 root root      4096 Sep 23  2021  frames
# -rw------- 1 root root   1560010 Mar 13  2020 'Getting started.pdf'
# drwx------ 2 root root      4096 Mar 29 05:24  kissing_images
# -rw------- 1 root root   9107527 May 25  2021  sub.mp4
# drwx------ 2 root root      4096 Mar 10  2021  TestData

# %%
import torch
import clip
from PIL import Image
import time
import glob
import numpy as np
import os
from itertools import islice
import pandas as pd
import subprocess
import datetime
from deepface import DeepFace
from deepface.commons import functions
from retinaface import RetinaFace
from sklearn.cluster import DBSCAN
from imutils import build_montages
import re
from imutils import paths
import face_recognition
import pickle
import cv2
import shutil
from collections import Counter

# %%
class CID:

    def __init__(self):
        self.device = "cuda" if torch.cuda.is_available() else "cpu"

    def load_clip(self):
        model, preprocess = clip.load("ViT-B/32", device=self.device)
        return model, preprocess

    def atoi(self, text):
        return int(text) if text.isdigit() else text

    def natural_keys(self, text):
        return [self.atoi(c) for c in re.split(r'(\d+)', text)]

    def formatTime1(self, x):
        x = str(x)
        try:
            return x.split("days")[1].strip()
        except:
            return x

    def extract_frames(self, UID, input_video):
        print(input_video)
        dest_folder_path = '/content/gdrive/MyDrive/cluster_faces/Frames/' + str(UID) + "/"
        print(dest_folder_path)
        if not os.path.exists(dest_folder_path):
            os.makedirs(dest_folder_path)
        fps = 1
        query = "ffmpeg -i " + input_video + " -pix_fmt rgb24 -vf fps=" + str(fps) + " " + dest_folder_path + "img_%06d.png"
        response = subprocess.Popen(query, shell=True, stdout=subprocess.PIPE).stdout.read()
        #subprocess.Popen(command, stderr=subprocess.PIPE, stdout=subprocess.PIPE)
        #response = subprocess.Popen(query, stderr=subprocess.PIPE, stdout=subprocess.PIPE)
        s = str(response).encode('utf-8')
        frames = []
        for file in glob.glob(dest_folder_path + '/*.png'):
            frames.append(file)
        frames.sort(key=self.natural_keys)
        print(frames)
        return frames

    def get_classes(self, celebrity_list):
        cl = []
        for i in celebrity_list:
            cl.append(f"a photo of {i}")
        cl.append("a photo of others")
        return cl

    def predict(self, fi, classes_list, model, preprocess):
        cl = classes_list
        text = clip.tokenize(cl).to(self.device)
        image = preprocess(Image.open(fi)).unsqueeze(0).to(self.device)
        with torch.no_grad():
            logits_per_image, logits_per_text = model(image, text)
            probs = logits_per_image.softmax(dim=-1).cpu().numpy()
            probs = probs.tolist()[0]
        vv = {}
        for i, j in enumerate(probs):
            vv[cl[i]] = j
        maxx = {k: v for k, v in sorted(vv.items(), key=lambda item: item[1], reverse=True)}
        tmp = list(islice(maxx.items(), 3))
        nn = fi.split('/')
        nn = nn[len(nn) - 1]
        print(f"{nn} => {tmp}")
        print('_____________________')
        return tmp

    def get_similarity(self, img1, img2):
        result = DeepFace.verify(img1_path=img1, img2_path=img2, detector_backend='skip', enforce_detection=False)
        return result['distance']

    def seconds2timestamp(self, sec):
        timestamp = datetime.timedelta(seconds=sec)
        return timestamp

    def decodePrediction(self, c1, s1):
        if c1 != 'a photo of others' or c1 != "a photo of an object":
            if s1 > 0.4:
                return "person"
        return "no_person"

    def timeStamp2seconds(self, timestring):
        pt = datetime.datetime.strptime(timestring, '%H:%M:%S')
        total_seconds = pt.second + pt.minute * 60 + pt.hour * 3600
        return total_seconds

    def checkStringPresent(self, wstring, sub_str):
        if wstring.find(sub_str) == -1:
            return False
        else:
            return True

    def get_images_with_person(self, frames_list, model, preprocess):
        persons_list = []
        classes_list = ["a photo of a person", "a photo of group of people", "a photo of other",
                        "a photo of a masked person", "a photo of two or more people", "a photo of a man",
                        "a photo of a woman", "a photo of a man and a women",
                        "a photo of an object"]
        for ind, fi in enumerate(frames_list):
            try:
                tmp = []
                Highest3Predictions = self.predict(fi, classes_list, model, preprocess)
                c1 = Highest3Predictions[0][0]
                s1 = Highest3Predictions[0][1]
                status = self.decodePrediction(c1, s1)
                if status == "person":
                    persons_list.append(fi)
            except:
                pass

        return persons_list

    def get_embeddings(self, img_paths, model):
        instances = {}
        for img_path in img_paths:
            try:
                img = functions.preprocess_face(img_path, target_size=(160, 160))
                # represent
                embeding = model.predict(img)[0].tolist()
                # raw image name without path and extension
                # label = img_path.split("/")[-1].split(".")[0]
                instances[img_path] = embeding
            except:
                pass
        return instances

    def extractFaces(self, images_path, id):
        saveFacesHere = '/content/gdrive/MyDrive/cluster_faces/Faces/' + str(id) + '/'
        saveFacesHere_forCLIP = '/content/gdrive/MyDrive/cluster_faces/Faces_Clip/' + str(id) + '/'
        if not os.path.exists(saveFacesHere):
            os.makedirs(saveFacesHere)
        if not os.path.exists(saveFacesHere_forCLIP):
            os.makedirs(saveFacesHere_forCLIP)
        df = pd.DataFrame(columns=["FacesPath", "FacesPathCLIP", "ImagePath", "TimeStamp", "FA1", "FA2", "FA3", "FA4"])

        # z = 0
        for image_path in images_path:
            z = image_path.split("/")
            z = z[len(z) - 1].split(".")[0]
            try:
                resp = RetinaFace.detect_faces(image_path)
                img = cv2.imread(image_path)
                image_wid = img.shape[1]
                image_hgt = img.shape[0]
                i = 0
                for key, value in resp.items():
                    tmp = []
                    aa = value['facial_area']
                    FA = [aa[1], aa[2], aa[3], aa[0]]
                    distnce_between_rightleft_eye = abs(
                        value['landmarks']['right_eye'][0] - value['landmarks']['left_eye'][0])
                    if distnce_between_rightleft_eye < 25:
                        pass
                    else:
                        x1, y1, x2, y2 = aa[0], aa[1], aa[2], aa[3]
                        x = x1
                        y = y1
                        w = abs(x2 - x1)
                        h = abs(y2 - y1)
                        crop_img = img[y:y + h, x:x + w]
                        wid = crop_img.shape[1]
                        hgt = crop_img.shape[0]

                        if (x + w + 50) <= image_wid:
                            croped_hight = y + h + 50
                        else:
                            croped_hight = y + h
                        if (y + h + 50) <= image_hgt:
                            croped_width = x + w + 50
                        else:
                            croped_width = x + w
                        crop_img_clip = img[y - 30:croped_hight, x - 30:croped_width]
                        if abs(wid - hgt) < 15:
                            pass
                        else:
                            cv2.imwrite(saveFacesHere + str(z) + "_" + str(i) + '.png', crop_img)
                            try:
                                cv2.imwrite(saveFacesHere_forCLIP + str(z) + "_" + str(i) + '.png', crop_img_clip)
                            except:
                                cv2.imwrite(saveFacesHere_forCLIP + str(z) + "_" + str(i) + '.png', crop_img)
                            tmp.append(saveFacesHere + str(z) + "_" + str(i) + '.png')
                            tmp.append(saveFacesHere_forCLIP + str(z) + "_" + str(i) + '.png')
                            tmp.append(image_path)
                            tmp.append(self.dfsec2t(z))
                            tmp.append(FA[0])
                            tmp.append(FA[1])
                            tmp.append(FA[2])
                            tmp.append(FA[3])
                            i += 1
                    if len(tmp) != 0:
                        df_length1 = len(df)
                        df.loc[df_length1] = tmp
            except Exception as e:
                # res[image_path] = []
                print('Error in cropping face :', e)

        return df

    def get_cluster(self, encodings_file_path, UID, data1):
        dest_folder_path = "/content/gdrive/MyDrive/cluster_faces/ClusterImage/" + str(UID) + "/"
        if not os.path.exists(dest_folder_path):
            os.makedirs(dest_folder_path)
        df = pd.DataFrame(columns=['Character ID', 'ImagePath'])
        print("[INFO] loading encodings...")
        data = pickle.loads(open(encodings_file_path, "rb").read())
        data = np.array(data)
        print(len(data))

        if len(data) <= 200:
            ms = 3
            ep = 0.5
        elif 200 < len(data) <= 300:
            ms = 5
            ep = 0.45
        elif 300 < len(data) <= 500:
            ms = 8
            ep = 0.42
        else:
            ms = 10
            ep = 0.39

        encodings = [d["encoding"] for d in data]
        nn = [ss["imagePath"] for ss in data1]
        # print(nn)
        # cluster the embeddings
        print("[INFO] clustering...")
        # clt = DBSCAN(metric="euclidean", n_jobs=args["jobs"])
        # eps=3, min_samples=2
        # algorithm{‘auto’, ‘ball_tree’, ‘kd_tree’, ‘brute’}, default=’auto’
        # leaf_sizeint, default=30
        # clt = DBSCAN(metric="euclidean", n_jobs=-1, eps=0.39, min_samples=24)
        clt = DBSCAN(metric="euclidean", n_jobs=-1, eps=ep, min_samples=ms)
        clt.fit(encodings)

        # determine the total number of unique faces found in the dataset
        labelIDs = np.unique(clt.labels_)
        numUniqueFaces = len(np.where(labelIDs > -1)[0])
        print("[INFO] # unique faces: {}".format(numUniqueFaces))
        # print(labelIDs)
        # print(numUniqueFaces)

        # loop over the unique face integers
        for labelID in labelIDs:
            # find all indexes into the `data` array that belong to the
            # current label ID, then randomly sample a maximum of 25 indexes
            # from the set
            print("[INFO] faces for face ID: {}".format(labelID))
            idxs = np.where(clt.labels_ == labelID)[0]
            a = []
            for i in idxs:
                a.append(nn[i])
            # print(idxs)
            a.sort(key=self.natural_keys)
            # print(a)
            tit = "Face ID #{}".format(labelID)
            ti = "Not Clustered Faces" if labelID == -1 else tit
            for zz in a:
                tmp = [ti, zz]
                df_length1 = len(df)
                df.loc[df_length1] = tmp

            idxs = np.random.choice(idxs, size=min(100, len(idxs)),
                                    replace=False)

            # initialize the list of faces to include in the montage
            faces = []

            # loop over the sampled indexes
            for i in idxs:
                # load the input image and extract the face ROI
                try:
                    image = cv2.imread(data[i]["imagePath"])
                    (top, right, bottom, left) = data[i]["loc"]
                    face = image[top:bottom, left:right]

                    # force resize the face ROI to 96x96 and then add it to the
                    # faces montage list
                    face = cv2.resize(face, (112, 112))
                    faces.append(face)
                except:
                    pass

            # create a montage using 96x96 "tiles" with 5 rows and 5 columns
            # print(faces)
            montage = build_montages(faces, (112, 112), (10, 15))[0]

            # show the output montage
            title = "Face ID #{}".format(labelID)
            title = "Unknown Faces" if labelID == -1 else title
            cv2.imwrite(dest_folder_path + str(title) + ".png", montage)
            # cv2.imshow(title, montage)
            # cv2.waitKey(0)

        return df

    def encode_faces(self, df, UID):
        # for (i, imagePath) in enumerate(imagePaths):
        data = []
        data1 = []
        pickle_file_path = "/content/gdrive/MyDrive/cluster_faces/pickle_files/" + str(UID) + ".pickle"
        for ind, row in df.iterrows():
            try:
                # load the input image and convert it from RGB (OpenCV ordering)
                # to dlib ordering (RGB)
                print("[INFO] processing image {}/{}".format(ind + 1, len(df)))
                # print(imagePath)
                image = cv2.imread(row['ImagePath'])
                rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

                # detect the (x, y)-coordinates of the bounding boxes
                # corresponding to each face in the input image
                # boxes = face_recognition.face_locations(rgb, model=args["detection_method"])
                boxes = [(int(row['FA1']), int(row['FA2']), int(row['FA3']), int(row['FA4']))]

                # compute the facial embedding for the face
                encodings = face_recognition.face_encodings(rgb, boxes)
                # Len of encodings : 128 d-vector

                # build a dictionary of the image path, bounding box location,
                # and facial encodings for the current image
                d = [{"imagePath": row['FacesPathCLIP'], "loc": box, "encoding": enc}
                     for (box, enc) in zip(boxes, encodings)]
                data.extend(d)

                d1 = [{"imagePath": row['ImagePath'], "loc": box, "encoding": enc}
                      for (box, enc) in zip(boxes, encodings)]
                data1.extend(d1)

            except Exception as e:
                print(row)
                print("Exception in Encoding", e)
                pass
        print("[INFO] serializing encodings...")
        f = open(pickle_file_path, "wb")
        f.write(pickle.dumps(data1))
        f.close()

        f1 = open("/content/gdrive/MyDrive/cluster_faces/pickle_files/" + str(UID) + "_1.pickle", "wb")
        f1.write(pickle.dumps(data))
        f1.close()
        return pickle_file_path, data

    def decode_actor_actress(self, c1, s1):
        if s1 >= 0.60:
            na = c1.split("a photo of ")[1]
            return na, s1, True
        else:
            na = c1.split("a photo of ")[1]
            return na, s1, False

    def format_line1(self, FrameName, p1, p2):
        dd = str(FrameName) + '\t' + str(p1) + '\t' + str(p2) + '\n'
        return dd

    def format_line(self, UID, type, time):
        dd = str(UID) + '\t' + str(type) + '\t' + str(time) + '\n'
        return dd

    def get_celebrity(self, frame, actor_actress_list, model, preprocess):
        Highest3Predictions = self.predict(frame, actor_actress_list, model, preprocess)
        c1 = Highest3Predictions[0][0]
        s1 = Highest3Predictions[0][1]
        c, s, st = self.decode_actor_actress(c1, s1)

        if st:
            return c
        else:
            return "unknown"

    def ti2sec(self, x):
        try:
            prev = datetime.datetime.strptime(str(x), '%H:%M:%S')
            prev = prev.second + prev.minute * 60 + prev.hour * 3600
            return prev
        except:
            return x

    def dfsec2t(self, a):
        try:
            a = int(a.split('_')[1])
            return self.seconds2timestamp(a)
        except:
            pass

    def formatTime(self, x):
        x = str(x)
        try:
            return x.split("days")[1].strip()
        except:
            return x

    def cluster_using_clip(self, UID, actor_actress_list, clip_model, preprocess):
        extract_faces_df = pd.read_csv("/content/gdrive/MyDrive/cluster_faces/DF/" + str(UID) + "_FacesExtract.csv")
        extract_faces_df["celebrity"] = " "
        for ind, row in extract_faces_df.iterrows():
            try:
                celeb = self.get_celebrity(row["FacesPathCLIP"], actor_actress_list, clip_model, preprocess)
                extract_faces_df["celebrity"].iloc[ind] = celeb
            except:
                extract_faces_df["celebrity"].iloc[ind] = "unknown"

        grouped_df = extract_faces_df.groupby(['celebrity'])
        s = []
        for key, item in grouped_df:
            a = grouped_df.get_group(key)
            s.append(a)
            # print(grouped_df.get_group(key), "\n\n")
        sss = pd.concat(s, ignore_index=True)
        sss["Character ID"] = ""
        ll = sss["celebrity"].tolist()
        prev = ll[0]
        a = 0
        for i, j in enumerate(ll):
            if i == 0:
                prev = ll[i]
                sss["Character ID"].iloc[i] = "Face ID #" + str(a)
            else:
                curr = ll[i]
                b = a
                if prev == curr:
                    if prev == "unknown":
                        sss["Character ID"].iloc[i] = "Not Clustered Faces"
                    else:
                        sss["Character ID"].iloc[i] = "Face ID #" + str(a)
                    # prev = curr
                else:
                    b += 1
                    if curr == "unknown":
                        sss["Character ID"].iloc[i] = "Not Clustered Faces"
                    else:
                        sss["Character ID"].iloc[i] = "Face ID #" + str(b)
                    a = b
                    prev = curr
        col = ["Character ID", "celebrity", "FacesPath", "ImagePath", "TimeStamp"]
        sss = sss[col]
        sss.columns = ['Character ID', 'Celebrity', 'FacePath', 'ImagePath', "TimeStamp"]
        return sss
        # extract_faces_df.to_csv("xxxx.csv")
        # print(extract_faces_df)

    def formatDF(self, df):
        try:
            df = df[(df['GTClassification'] != "neutral")]
            df["TimeStamp"] = df["Seconds"].apply(self.seconds2timestamp).apply(self.formatTime)
            return df
        except:
            return df

    def start_process(self, UID, celebrity_list, input_video_path):
        frames_list = self.extract_frames(UID, input_video_path)
        # frames_list = [FramesPath + 'img_' + str(self.ti2sec(i)).zfill(6) + '.png' for i in tim]
        # frames_list = list(set(frames_list))
        frames_list.sort(key=self.natural_keys)
        #
        clip_model, preprocess = self.load_clip()
        frames_with_person = self.get_images_with_person(frames_list, clip_model, preprocess)
        #
        extract_faces_df = self.extractFaces(frames_with_person, UID)
        extract_faces_df["TimeStamp"] = extract_faces_df["TimeStamp"].apply(self.formatTime)
        extract_faces_df.to_csv('/content/gdrive/My Drive/cluster_faces/DF/' + str(UID) + "_FacesExtract" + '.csv')
        print(extract_faces_df)
        #
        pickle_file_path, data = self.encode_faces(extract_faces_df, UID)
        print(pickle_file_path)
        #
        df = self.get_cluster(pickle_file_path, UID, data)
        df["FacePath"] = " "
        df["TimeStamp"] = " "
        df["Celebrity"] = " "
        if len(celebrity_list) != 0:
            actor_actress_list = self.get_classes(celebrity_list)
        else:
            actor_actress_list = []
        for ind, row in df.iterrows():
            try:
                aa = extract_faces_df[(extract_faces_df['FacesPathCLIP'] == row["ImagePath"])]["ImagePath"].tolist()[0]
                face_path = extract_faces_df['FacesPathCLIP'].iloc[ind]
                # bb = extract_faces_df['TimeStamp'].iloc[ind]
                df["FacePath"].iloc[ind] = aa
                bc = extract_faces_df[(extract_faces_df['ImagePath'] == row["FacePath"])]["TimeStamp"].tolist()[0]
                df["TimeStamp"].iloc[ind] = bc
                # df["TimeStamp"].iloc[ind] = bb
                if len(actor_actress_list) != 0:
                    # celeb = self.get_celebrity(face_path, actor_actress_list, clip_model, preprocess)
                    df["Celebrity"].iloc[ind] = "unknown"
                else:
                    df["Celebrity"].iloc[ind] = "unknown"
            except:
                pass
        #
        col = ["Character ID", "Celebrity", "FacePath", "ImagePath", "TimeStamp"]
        df = df[col]
        df.columns = ['Character ID', 'Celebrity', 'ImagePath', 'FacePath', "TimeStamp"]

        df.to_csv('/content/gdrive/My Drive/cluster_faces/DF/' + str(UID) + "_cluster" + '.csv')
        print(df)

        if len(celebrity_list) != 0:
            actor_actress_list = self.get_classes(celebrity_list)
            sss = self.cluster_using_clip(UID, actor_actress_list, clip_model, preprocess)
            sss.to_csv('/content/gdrive/My Drive/cluster_faces/CLIP_DF/' + str(UID) + "_cluster" + '.csv')
        else:
            actor_actress_list = []
            # pickle_file_path, data = self.encode_faces(extract_faces_df, UID)
            # print(pickle_file_path)
            # df = self.get_cluster(pickle_file_path, UID, data)

# %%
obj = CID()

celebrity_list = ["Leonardo DiCaprio","Mark Ruffalo","Ben Kingsley","Michelle Williams","Emily Mortimer","Patricia Clarkson","Max von Sydow"]
obj.start_process(77, celebrity_list, "/content/gdrive/MyDrive/cluster_faces/Shutter_Island.mp4")
# Out:
# /content/gdrive/MyDrive/cluster_faces/Shutter_Island.mp4
# /content/gdrive/MyDrive/cluster_faces/Frames/77/
# ['/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000001.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000002.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000003.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000004.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000005.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000006.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000007.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000008.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000009.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000010.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000011.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000012.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000013.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000014.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000015.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000016.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000017.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000018.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000019.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000020.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000021.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000022.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000023.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000024.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000025.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000026.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000027.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000028.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000029.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000030.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000031.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000032.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000033.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000034.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000035.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000036.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000037.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000038.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000039.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000040.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000041.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000042.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000043.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000044.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000045.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000046.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000047.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000048.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000049.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000050.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000051.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000052.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000053.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000054.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000055.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000056.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000057.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000058.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000059.png', '/content/gdrive/MyDrive/cluster_faces/Frames/77/img_000060.png', '/content/gdrive/MyDrive/cluster_faces/ ...
# 100%|███████████████████████████████████████| 338M/338M [00:05<00:00, 59.1MiB/s]
# img_000001.png => [('a photo of a man', 0.414306640625), ('a photo of other', 0.208251953125), ('a photo of a man and a women', 0.1500244140625)]
# _____________________
# img_000002.png => [('a photo of a man', 0.360107421875), ('a photo of a man and a women', 0.201904296875), ('a photo of other', 0.17822265625)]
# _____________________
# img_000003.png => [('a photo of a man', 0.277099609375), ('a photo of a man and a women', 0.2261962890625), ('a photo of other', 0.21240234375)]
# _____________________
# img_000004.png => [('a photo of other', 0.312255859375), ('a photo of a man', 0.262939453125), ('a photo of a man and a women', 0.1697998046875)]
# _____________________
# img_000005.png => [('a photo of two or more people', 0.22412109375), ('a photo of group of people', 0.1947021484375), ('a photo of other', 0.188720703125)]
# _____________________
# img_000006.png => [('a photo of two or more people', 0.276123046875), ('a photo of other', 0.2254638671875), ('a photo of a man and a women', 0.1839599609375)]
# _____________________
# img_000007.png => [('a photo of two or more people', 0.37451171875), ('a photo of other', 0.21337890625), ('a photo of a man and a women', 0.1973876953125)]
# _____________________
# img_000008.png => [('a photo of two or more people', 0.36181640625), ('a photo of other', 0.222900390625), ('a photo of a man and a women', 0.187744140625)]
# _____________________
# img_000009.png => [('a photo of two or more people', 0.36474609375), ('a photo of other', 0.228271484375), ('a photo of a man and a women', 0.149658203125)]
# _____________________
# img_000010.png => [('a photo of two or more people', 0.401123046875), ('a photo of other', 0.228515625), ('a photo of a man and a women', 0.1522216796875)]
# _____________________
# img_000011.png => [('a photo of two or more people', 0.273681640625), ('a photo of other', 0.269287109375), ('a photo of a man and a women', 0.1822509765625)]
# _____________________
# img_000012.png => [('a photo of two or more people', 0.270751953125), ('a photo of other', 0.235107421875), ('a photo of a man and a women', 0.19189453125)]
# _____________________
# img_000013.png => [('a photo of two or more people', 0.356689453125), ('a photo of a man and a women', 0.2452392578125), ('a photo of other', 0.1583251953125)]
# _____________________
# img_000014.png => [('a photo of two or more people', 0.332763671875), ('a photo of other', 0.2322998046875), ('a photo of a man', 0.13232421875)]
# _____________________
# img_000015.png => [('a photo of two or more people', 0.45654296875), ('a photo of other', 0.244384765625), ('a photo of a man and a women', 0.11724853515625)]
# _____________________
# img_000016.png => [('a photo of two or more people', 0.396728515625), ('a photo of other', 0.218994140625), ('a photo of a man and a women', 0.1552734375)]
# _____________________
# img_000017.png => [('a photo of two or more people', 0.356689453125), ('a photo of other', 0.1793212890625), ('a photo of a man and a women', 0.1534423828125)]
# _____________________
# img_000018.png => [('a photo of two or more people', 0.296630859375), ('a photo of other', 0.2459716796875), ('a photo of group of people', 0.217041015625)]
# _____________________
# img_000019.png => [('a photo of group of people', 0.255126953125), ('a photo of other', 0.2322998046875), ('a photo of two or more people', 0.2286376953125)]
# _____________________
# img_000020.png => [('a photo of two or more people', 0.29248046875), ('a photo of other', 0.2425537109375), ('a photo of a man and a women', 0.1666259765625)]
# _____________________
# img_000021.png => [('a photo of two or more people', 0.271240234375), ('a photo of a man and a women', 0.2393798828125), ('a photo of a man', 0.1671142578125)]
# _____________________
# img_000022.png => [('a photo of two or more people', 0.291748046875), ('a photo of a man and a women', 0.269775390625), ('a photo of a man', 0.166259765625)]
# _____________________
# img_000023.png => [('a photo of two or more people', 0.306640625), ('a photo of a man and a women', 0.270751953125), ('a photo of other', 0.1719970703125)]
# _____________________
# img_000024.png => [('a photo of two or more people', 0.387451171875), ('a photo of other', 0.246337890625), ('a photo of a man and a women', 0.1541748046875)]
# _____________________
# img_000025.png => [('a photo of two or more people', 0.3564453125), ('a photo of other', 0.203125), ('a photo of a man and a women', 0.17919921875)]
# _____________________
# img_000026.png => [('a photo of two or more people', 0.3662109375), ('a photo of a man and a women', 0.21875), ('a photo of other', 0.1702880859375)]
# _____________________
# img_000027.png => [('a photo of two or more people', 0.37939453125), ('a photo of a man and a women', 0.2196044921875), ('a photo of other', 0.1683349609375)]
# _____________________
# img_000028.png => [('a photo of two or more people', 0.4052734375), ('a photo of a man and a women', 0.213623046875), ('a photo of other', 0.15869140625)]
# _____________________
# img_000029.png => [('a photo of two or more people', 0.278564453125), ('a photo of other', 0.2103271484375), ('a photo of group of people', 0.171630859375)]
# _____________________
# img_000030.png => [('a photo of two or more people', 0.3056640625), ('a photo of other', 0.2069091796875), ('a photo of a man and a women', 0.2069091796875)]
# _____________________
# img_000031.png => [('a photo of two or more people', 0.36181640625), ('a photo of a man and a women', 0.216064453125), ('a photo of other', 0.1556396484375)]
# _____________________
# img_000032.png => [('a photo of two or more people', 0.38232421875), ('a photo of a man and a women', 0.2430419921875), ('a photo of other', 0.1363525390625)]
# _____________________
# img_000033.png => [('a photo of two or more people', 0.401123046875), ('a photo of a man and a women', 0.232177734375), ('a photo of other', 0.136474609375)]
# _____________________
# img_000034.png => [('a photo of two or more people', 0.3994140625), ('a photo of a man and a women', 0.2423095703125), ('a photo of other', 0.11810302734375)]
# _____________________
# img_000035.png => [('a photo of two or more people', 0.413818359375), ('a photo of a man and a women', 0.2548828125), ('a photo of other', 0.1185302734375)]
# _____________________
# img_000036.png => [('a photo of two or more people', 0.405517578125), ('a photo of a man and a women', 0.1744384765625), ('a photo of other', 0.14453125)]
# _____________________
# img_000037.png => [('a photo of a man', 0.25927734375), ('a photo of two or more people', 0.2288818359375), ('a photo of a man and a women', 0.2149658203125)]
# _____________________
# img_000038.png => [('a photo of a man and a women', 0.2578125), ('a photo of other', 0.2239990234375), ('a photo of two or more people', 0.2039794921875)]
# _____________________
# img_000039.png => [('a photo of a man and a women', 0.316650390625), ('a photo of two or more people', 0.270751953125), ('a photo of other', 0.1617431640625)]
# _____________________
# img_000040.png => [('a photo of two or more people', 0.416748046875), ('a photo of a man and a women', 0.2095947265625), ('a photo of other', 0.158203125)]
# _____________________
# img_000041.png => [('a photo of two or more people', 0.405029296875), ('a photo of a man and a women', 0.22021484375), ('a photo of other', 0.1561279296875)]
# _____________________
# img_000042.png => [('a photo of other', 0.323974609375), ('a photo of two or more people', 0.1875), ('a photo of a man and a women', 0.1553955078125)]
# _____________________
# img_000043.png => [('a photo of other', 0.279296875), ('a photo of two or more people', 0.2244873046875), ('a photo of a man and a women', 0.1802978515625)]
# _____________________
# img_000044.png => [('a photo of a man', 0.71826171875), ('a photo of a person', 0.1602783203125), ('a photo of other', 0.056243896484375)]
# _____________________
# img_000045.png => [('a photo of a man', 0.75439453125), ('a photo of a person', 0.1331787109375), ('a photo of other', 0.061920166015625)]
# _____________________
# img_000046.png => [('a photo of a man', 0.6806640625), ('a photo of a person', 0.147216796875), ('a photo of other', 0.07403564453125)]
# _____________________
# img_000047.png => [('a photo of a man', 0.26806640625), ('a photo of a man and a women', 0.251708984375), ('a photo of two or more people', 0.2327880859375)]
# _____________________
# img_000048.png => [('a photo of a man', 0.280517578125), ('a photo of two or more people', 0.25537109375), ('a photo of a man and a women', 0.225341796875)]
# _____________________
# img_000049.png => [('a photo of two or more people', 0.32177734375), ('a photo of a man', 0.231689453125), ('a photo of a man and a women', 0.224609375)]
# _____________________
# img_000050.png => [('a photo of a man and a women', 0.28662109375), ('a photo of two or more people', 0.264892578125), ('a photo of a man', 0.230224609375)]
# _____________________
# img_000051.png => [('a photo of a man and a women', 0.269775390625), ('a photo of two or more people', 0.257568359375), ('a photo of a man', 0.241943359375)]
# _____________________
# img_000052.png => [('a photo of a man', 0.24365234375), ('a photo of a man and a women', 0.232421875), ('a photo of two or more people', 0.2149658203125)]
# _____________________
# img_000053.png => [('a photo of a man', 0.6328125), ('a photo of other', 0.11346435546875), ('a photo of two or more people', 0.0804443359375)]
# _____________________
# img_000054.png => [('a photo of a man', 0.64794921875), ('a photo of other', 0.109130859375), ('a photo of two or more people', 0.076171875)]
# _____________________
# img_000055.png => [('a photo of a man', 0.485107421875), ('a photo of other', 0.178466796875), ('a photo of two or more people', 0.1368408203125)]
# _____________________
# img_000056.png => [('a photo of a man', 0.447509765625), ('a photo of other', 0.1751708984375), ('a photo of two or more people', 0.13427734375)]
# _____________________
# img_000057.png => [('a photo of two or more people', 0.33154296875), ('a photo of other', 0.2314453125), ('a photo of a man and a women', 0.16162109375)]
# _____________________
# img_000058.png => [('a photo of a man', 0.445556640625), ('a photo of a man and a women', 0.151611328125), ('a photo of other', 0.1402587890625)]
# _____________________
# img_000059.png => [('a photo of a man', 0.49169921875), ('a photo of a man and a women', 0.14306640625), ('a photo of two or more people', 0.1365966796875)]
# _____________________
# img_000060.png => [('a photo of a man', 0.4404296875), ('a photo of a man and a women', 0.1751708984375), ('a photo of two or more people', 0.14306640625)]
# _____________________
# img_000061.png => [('a photo of a man', 0.28955078125), ('a photo of a man and a women', 0.205322265625), ('a photo of two or more people', 0.1898193359375)]
# _____________________
# img_000062.png => [('a photo of two or more people', 0.26025390625), ('a photo of a man and a women', 0.24072265625), ('a photo of a man', 0.2369384765625)]
# _____________________
# img_000063.png => [('a photo of a man', 0.28466796875), ('a photo of two or more people', 0.228759765625), ('a photo of a man and a women', 0.2115478515625)]
# _____________________
# img_000064.png => [('a photo of a man', 0.37890625), ('a photo of a man and a women', 0.2193603515625), ('a photo of two or more people', 0.1416015625)]
# _____________________
# img_000065.png => [('a photo of a man', 0.350830078125), ('a photo of a man and a women', 0.216064453125), ('a photo of two or more people', 0.1708984375)]
# _____________________
# img_000066.png => [('a photo of a man', 0.2421875), ('a photo of a man and a women', 0.2239990234375), ('a photo of two or more people', 0.2137451171875)]
# _____________________
# img_000067.png => [('a photo of a man', 0.275390625), ('a photo of a man and a women', 0.27099609375), ('a photo of two or more people', 0.175048828125)]
# _____________________
# img_000068.png => [('a photo of a man', 0.2296142578125), ('a photo of a man and a women', 0.22607421875), ('a photo of two or more people', 0.2191162109375)]
# _____________________
# img_000069.png => [('a photo of two or more people', 0.348388671875), ('a photo of a man and a women', 0.2113037109375), ('a photo of other', 0.1671142578125)]
# _____________________
# img_000070.png => [('a photo of two or more people', 0.277099609375), ('a photo of a man', 0.26025390625), ('a photo of a man and a women', 0.209228515625)]
# _____________________
# img_000071.png => [('a photo of a man', 0.466064453125), ('a photo of a man and a women', 0.1661376953125), ('a photo of two or more people', 0.14892578125)]
# _____________________
# img_000072.png => [('a photo of a man', 0.30712890625), ('a photo of two or more people', 0.207763671875), ('a photo of other', 0.189208984375)]
# _____________________
# img_000073.png => [('a photo of a man', 0.3330078125), ('a photo of a man and a women', 0.24365234375), ('a photo of two or more people', 0.2020263671875)]
# _____________________
# img_000074.png => [('a photo of a man', 0.31103515625), ('a photo of two or more people', 0.2171630859375), ('a photo of a man and a women', 0.2171630859375)]
# _____________________
# img_000075.png => [('a photo of other', 0.37060546875), ('a photo of group of people', 0.27978515625), ('a photo of a man and a women', 0.11480712890625)]
# _____________________
# img_000076.png => [('a photo of other', 0.356201171875), ('a photo of a man and a women', 0.2371826171875), ('a photo of group of people', 0.193603515625)]
# _____________________
# img_000077.png => [('a photo of other', 0.468994140625), ('a photo of group of people', 0.288818359375), ('a photo of a man and a women', 0.0718994140625)]
# _____________________
# img_000078.png => [('a photo of other', 0.5361328125), ('a photo of group of people', 0.296142578125), ('a photo of an object', 0.07843017578125)]
# _____________________
# img_000079.png => [('a photo of group of people', 0.474853515625), ('a photo of other', 0.3935546875), ('a photo of a man', 0.050048828125)]
# _____________________
# img_000080.png => [('a photo of other', 0.490478515625), ('a photo of group of people', 0.279541015625), ('a photo of an object', 0.0633544921875)]
# _____________________
# img_000081.png => [('a photo of other', 0.454345703125), ('a photo of group of people', 0.364990234375), ('a photo of an object', 0.055999755859375)]
# _____________________
# img_000082.png => [('a photo of other', 0.480712890625), ('a photo of group of people', 0.38037109375), ('a photo of an object', 0.06927490234375)]
# _____________________
# img_000083.png => [('a photo of other', 0.483642578125), ('a photo of group of people', 0.2509765625), ('a photo of an object', 0.0894775390625)]
# _____________________
# img_000084.png => [('a photo of a man', 0.274169921875), ('a photo of a person', 0.257568359375), ('a photo of other', 0.166259765625)]
# _____________________
# img_000085.png => [('a photo of a man', 0.32421875), ('a photo of a person', 0.226318359375), ('a photo of other', 0.1790771484375)]
# _____________________
# img_000086.png => [('a photo of a man', 0.307861328125), ('a photo of a person', 0.263427734375), ('a photo of other', 0.147705078125)]
# _____________________
# img_000087.png => [('a photo of a man and a women', 0.287109375), ('a photo of a man', 0.25732421875), ('a photo of two or more people', 0.2305908203125)]
# _____________________
# img_000088.png => [('a photo of a man', 0.308349609375), ('a photo of a man and a women', 0.240234375), ('a photo of two or more people', 0.2255859375)]
# _____________________
# img_000089.png => [('a photo of a man', 0.306884765625), ('a photo of a man and a women', 0.25439453125), ('a photo of two or more people', 0.2012939453125)]
# _____________________
# img_000090.png => [('a photo of a man', 0.2578125), ('a photo of two or more people', 0.23486328125), ('a photo of other', 0.188720703125)]
# _____________________
# img_000091.png => [('a photo of a man', 0.258056640625), ('a photo of two or more people', 0.250244140625), ('a photo of other', 0.1917724609375)]
# _____________________
# img_000092.png => [('a photo of a man', 0.301513671875), ('a photo of two or more people', 0.2347412109375), ('a photo of other', 0.179931640625)]
# _____________________
# img_000093.png => [('a photo of a man', 0.30908203125), ('a photo of two or more people', 0.2369384765625), ('a photo of other', 0.162841796875)]
# _____________________
# img_000094.png => [('a photo of a man', 0.31689453125), ('a photo of two or more people', 0.2281494140625), ('a photo of other', 0.1669921875)]
# _____________________
# img_000095.png => [('a photo of two or more people', 0.25), ('a photo of a man', 0.25), ('a photo of a man and a women', 0.207275390625)]
# _____________________
# img_000096.png => [('a photo of a man', 0.2578125), ('a photo of two or more people', 0.217041015625), ('a photo of a man and a women', 0.217041015625)]
# _____________________
# img_000097.png => [('a photo of two or more people', 0.2413330078125), ('a photo of a man', 0.2413330078125), ('a photo of a man and a women', 0.19384765625)]
# _____________________
# img_000098.png => [('a photo of two or more people', 0.28369140625), ('a photo of a man and a women', 0.2142333984375), ('a photo of a man', 0.1920166015625)]
# _____________________
# img_000099.png => [('a photo of other', 0.2398681640625), ('a photo of two or more people', 0.2362060546875), ('a photo of a man', 0.211669921875)]
# _____________________
# img_000100.png => [('a photo of two or more people', 0.263671875), ('a photo of a man and a women', 0.24755859375), ('a photo of other', 0.198974609375)]
# _____________________
# img_000101.png => [('a photo of two or more people', 0.2509765625), ('a photo of a man and a women', 0.2249755859375), ('a photo of other', 0.20166015625)]
# _____________________
# img_000102.png => [('a photo of two or more people', 0.255615234375), ('a photo of a man and a women', 0.2476806640625), ('a photo of a man', 0.2021484375)]
# _____________________
# img_000103.png => [('a photo of two or more people', 0.2432861328125), ('a photo of a man and a women', 0.2432861328125), ('a photo of other', 0.20166015625)]
# _____________________
# img_000104.png => [('a photo of a man', 0.52734375), ('a photo of other', 0.1766357421875), ('a photo of a man and a women', 0.0960693359375)]
# _____________________
# img_000105.png => [('a photo of a man', 0.5859375), ('a photo of other', 0.1602783203125), ('a photo of a person', 0.076904296875)]
# _____________________
# img_000106.png => [('a photo of a man', 0.53662109375), ('a photo of other', 0.2037353515625), ('a photo of a person', 0.08624267578125)]
# _____________________
# img_000107.png => [('a photo of a man', 0.416748046875), ('a photo of other', 0.2196044921875), ('a photo of a man and a women', 0.121337890625)]
# _____________________
# img_000108.png => [('a photo of other', 0.43115234375), ('a photo of two or more people', 0.2236328125), ('a photo of a man and a women', 0.12164306640625)]
# _____________________
# img_000109.png => [('a photo of other', 0.47998046875), ('a photo of a man', 0.209716796875), ('a photo of two or more people', 0.10223388671875)]
# _____________________
# img_000110.png => [('a photo of other', 0.467529296875), ('a photo of a man', 0.2174072265625), ('a photo of a man and a women', 0.09796142578125)]
# _____________________
# img_000111.png => [('a photo of a man', 0.470703125), ('a photo of other', 0.2294921875), ('a photo of a man and a women', 0.136962890625)]
# _____________________
# img_000112.png => [('a photo of a man', 0.45849609375), ('a photo of other', 0.25732421875), ('a photo of a person', 0.0875244140625)]
# _____________________
# img_000113.png => [('a photo of other', 0.374755859375), ('a photo of a man', 0.315673828125), ('a photo of a person', 0.1490478515625)]
# _____________________
# img_000114.png => [('a photo of a man', 0.337158203125), ('a photo of other', 0.254638671875), ('a photo of a person', 0.13623046875)]
# _____________________
# img_000115.png => [('a photo of other', 0.4169921875), ('a photo of a man and a women', 0.1396484375), ('a photo of a man', 0.1251220703125)]
# _____________________
# img_000116.png => [('a photo of a man', 0.47314453125), ('a photo of other', 0.278076171875), ('a photo of a man and a women', 0.10076904296875)]
# _____________________
# img_000117.png => [('a photo of other', 0.419189453125), ('a photo of group of people', 0.34228515625), ('a photo of a man', 0.08258056640625)]
# _____________________
# img_000118.png => [('a photo of group of people', 0.51123046875), ('a photo of other', 0.385986328125), ('a photo of a man', 0.0394287109375)]
# _____________________
# img_000119.png => [('a photo of group of people', 0.6201171875), ('a photo of other', 0.306884765625), ('a photo of a man', 0.0318603515625)]
# _____________________
# img_000120.png => [('a photo of group of people', 0.53662109375), ('a photo of other', 0.392578125), ('a photo of a man', 0.03887939453125)]
# _____________________
# img_000121.png => [('a photo of a man', 0.6748046875), ('a photo of a person', 0.1845703125), ('a photo of other', 0.0657958984375)]
# _____________________
# img_000122.png => [('a photo of a man', 0.646484375), ('a photo of a person', 0.194091796875), ('a photo of other', 0.068115234375)]
# _____________________
# img_000123.png => [('a photo of a man', 0.685546875), ('a photo of a person', 0.1068115234375), ('a photo of other', 0.08062744140625)]
# _____________________
# img_000124.png => [('a photo of a man', 0.51171875), ('a photo of other', 0.1466064453125), ('a photo of a man and a women', 0.1466064453125)]
# _____________________
# img_000125.png => [('a photo of a man and a women', 0.52392578125), ('a photo of other', 0.186767578125), ('a photo of two or more people', 0.1572265625)]
# _____________________
# img_000126.png => [('a photo of group of people', 0.499755859375), ('a photo of other', 0.427490234375), ('a photo of a man', 0.042327880859375)]
# _____________________
# img_000127.png => [('a photo of group of people', 0.5673828125), ('a photo of other', 0.378173828125), ('a photo of a man', 0.024169921875)]
# _____________________
# img_000128.png => [('a photo of group of people', 0.609375), ('a photo of other', 0.34716796875), ('a photo of a man', 0.0181121826171875)]
# _____________________
# img_000129.png => [('a photo of group of people', 0.57470703125), ('a photo of other', 0.370849609375), ('a photo of a man', 0.023345947265625)]
# _____________________
# img_000130.png => [('a photo of group of people', 0.609375), ('a photo of other', 0.352783203125), ('a photo of a man', 0.0157470703125)]
# _____________________
# img_000131.png => [('a photo of group of people', 0.70654296875), ('a photo of other', 0.2724609375), ('a photo of a man', 0.007488250732421875)]
# _____________________
# img_000132.png => [('a photo of other', 0.740234375), ('a photo of a man and a women', 0.081787109375), ('a photo of group of people', 0.05621337890625)]
# _____________________
# img_000133.png => [('a photo of other', 0.705078125), ('a photo of a man and a women', 0.0999755859375), ('a photo of group of people', 0.0465087890625)]
# _____________________
# img_000134.png => [('a photo of other', 0.76318359375), ('a photo of a man and a women', 0.0985107421875), ('a photo of group of people', 0.047271728515625)]
# _____________________
# img_000135.png => [('a photo of other', 0.73974609375), ('a photo of a man and a women', 0.10491943359375), ('a photo of group of people', 0.0535888671875)]
# _____________________
# img_000136.png => [('a photo of other', 0.74072265625), ('a photo of a man and a women', 0.09710693359375), ('a photo of group of people', 0.064697265625)]
# _____________________
# img_000137.png => [('a photo of other', 0.79345703125), ('a photo of group of people', 0.07977294921875), ('a photo of a man and a women', 0.047637939453125)]
# _____________________
# img_000138.png => [('a photo of other', 0.76318359375), ('a photo of a man and a women', 0.06884765625), ('a photo of a man', 0.05194091796875)]
# _____________________
# img_000139.png => [('a photo of other', 0.71533203125), ('a photo of a man', 0.0665283203125), ('a photo of group of people', 0.059661865234375)]
# _____________________
# img_000140.png => [('a photo of other', 0.7109375), ('a photo of a man', 0.0726318359375), ('a photo of group of people', 0.053985595703125)]
# _____________________
# img_000141.png => [('a photo of other', 0.70556640625), ('a photo of a man', 0.06878662109375), ('a photo of group of people', 0.058837890625)]
# _____________________
# img_000142.png => [('a photo of other', 0.69970703125), ('a photo of a man', 0.07147216796875), ('a photo of group of people', 0.0601806640625)]
# _____________________
# img_000143.png => [('a photo of other', 0.8671875), ('a photo of group of people', 0.02459716796875), ('a photo of a masked person', 0.0227508544921875)]
# _____________________
# img_000144.png => [('a photo of other', 0.81884765625), ('a photo of a masked person', 0.06719970703125), ('a photo of an object', 0.03485107421875)]
# _____________________
# img_000145.png => [('a photo of other', 0.83154296875), ('a photo of a masked person', 0.059295654296875), ('a photo of an object', 0.032745361328125)]
# _____________________
# img_000146.png => [('a photo of other', 0.82421875), ('a photo of a masked person', 0.06353759765625), ('a photo of an object', 0.03399658203125)]
# _____________________
# img_000147.png => [('a photo of other', 0.826171875), ('a photo of a masked person', 0.059844970703125), ('a photo of an object', 0.029632568359375)]
# _____________________
# img_000148.png => [('a photo of other', 0.658203125), ('a photo of group of people', 0.149169921875), ('a photo of an object', 0.0948486328125)]
# _____________________
# img_000149.png => [('a photo of other', 0.525390625), ('a photo of an object', 0.244384765625), ('a photo of group of people', 0.07220458984375)]
# _____________________
# img_000150.png => [('a photo of other', 0.52978515625), ('a photo of an object', 0.250244140625), ('a photo of group of people', 0.06732177734375)]
# _____________________
# img_000151.png => [('a photo of other', 0.52734375), ('a photo of an object', 0.2529296875), ('a photo of group of people', 0.0670166015625)]
# _____________________
# img_000152.png => [('a photo of other', 0.529296875), ('a photo of an object', 0.238525390625), ('a photo of group of people', 0.07159423828125)]
# _____________________
# img_000153.png => [('a photo of other', 0.68994140625), ('a photo of an object', 0.1380615234375), ('a photo of group of people', 0.07861328125)]
# _____________________
# img_000154.png => [('a photo of other', 0.7705078125), ('a photo of an object', 0.09796142578125), ('a photo of group of people', 0.06732177734375)]
# _____________________
# img_000155.png => [('a photo of other', 0.77294921875), ('a photo of an object', 0.10791015625), ('a photo of group of people', 0.0634765625)]
# _____________________
# img_000156.png => [('a photo of other', 0.77294921875), ('a photo of an object', 0.10791015625), ('a photo of group of people', 0.0634765625)]
# _____________________
# img_000157.png => [('a photo of other', 0.619140625), ('a photo of an object', 0.2425537109375), ('a photo of group of people', 0.04150390625)]
# _____________________
# img_000158.png => [('a photo of an object', 0.47265625), ('a photo of other', 0.2452392578125), ('a photo of group of people', 0.2164306640625)]
# _____________________
# img_000159.png => [('a photo of an object', 0.48828125), ('a photo of other', 0.30078125), ('a photo of group of people', 0.168701171875)]
# _____________________
# img_000160.png => [('a photo of an object', 0.42578125), ('a photo of other', 0.27490234375), ('a photo of group of people', 0.24267578125)]
# _____________________
# img_000161.png => [('a photo of an object', 0.39208984375), ('a photo of other', 0.282470703125), ('a photo of group of people', 0.26123046875)]
# _____________________
# retinaface.h5 will be downloaded from the url https://github.com/serengil/deepface_models/releases/download/v1.0/retinaface.h5
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/retinaface.h5
# To: /root/.deepface/weights/retinaface.h5
# 100%|██████████| 119M/119M [00:31<00:00, 3.75MB/s]
# Error in cropping face : 'tuple' object has no attribute 'items'
# Error in cropping face : 'tuple' object has no attribute 'items'
# Error in cropping face : 'tuple' object has no attribute 'items'
# Error in cropping face : 'tuple' object has no attribute 'items'
# Error in cropping face : 'tuple' object has no attribute 'items'
# Error in cropping face : 'tuple' object has no attribute 'items'
# Error in cropping face : 'tuple' object has no attribute 'items'
# Error in cropping face : 'tuple' object has no attribute 'items'
# Error in cropping face : 'tuple' object has no attribute 'items'
#                                             FacesPath  \
# 0   /content/gdrive/MyDrive/cluster_faces/Faces/77...
# 1   /content/gdrive/MyDrive/cluster_faces/Faces/77...
# 2   /content/gdrive/MyDrive/cluster_faces/Faces/77...
# 3   /content/gdrive/MyDrive/cluster_faces/Faces/77...
# 4   /content/gdrive/MyDrive/cluster_faces/Faces/77...
# ..                                                ...
# 70  /content/gdrive/MyDrive/cluster_faces/Faces/77...
# 71  /content/gdrive/MyDrive/cluster_faces/Faces/77...
# 72  /content/gdrive/MyDrive/cluster_faces/Faces/77...
# 73  /content/gdrive/MyDrive/cluster_faces/Faces/77...
# 74  /content/gdrive/MyDrive/cluster_faces/Faces/77...
#
#                                         FacesPathCLIP  \
# 0   /content/gdrive/MyDrive/cluster_faces/Faces_Cl...
# 1   /content/gdrive/MyDrive/cluster_faces/Faces_Cl...
# 2   /content/gdrive/MyDrive/cluster_faces/Faces_Cl...
# 3   /content/gdrive/MyDrive/cluster_faces/Faces_Cl...
# 4   /content/gdrive/MyDrive/cluster_faces/Faces_Cl...
# ..                                                ...
# 70  /content/gdrive/MyDrive/cluster_faces/Faces_Cl...
# 71  /content/gdrive/MyDrive/cluster_faces/Faces_Cl...
# 72  /content/gdrive/MyDrive/cluster_faces/Faces_Cl...
# 73  /content/gdrive/MyDrive/cluster_faces/Faces_Cl...
# 74  /content/gdrive/MyDrive/cluster_faces/Faces_Cl...
#
#                                             ImagePath TimeStamp  FA1  FA2  \
# 0   /content/gdrive/MyDrive/cluster_faces/Frames/7...  00:00:01  140  704
# 1   /content/gdrive/MyDrive/cluster_faces/Frames/7...  00:00:10  177  581
# 2   /content/gdrive/MyDrive/cluster_faces/Frames/7...  00:00:10  142  892
# 3   /content/gdrive/MyDrive/cluster_faces/Frames/7...  00:00:15  194  551
# 4   /content/gdrive/MyDrive/cluster_faces/Frames/7...  00:00:28  144  903
# ..                                                ...       ...  ...  ...
# 70  /content/gdrive/MyDrive/cluster_faces/Frames/7...  00:02:24  462  179
# 71  /content/gdrive/MyDrive/cluster_faces/Frames/7...  00:02:25  315  281
# 72  /content/gdrive/MyDrive/cluster_faces/Frames/7...  00:02:26  318   97
# 73  /content/gdrive/MyDrive/cluster_faces/Frames/7...  00:02:26  318  285
# 74  /content/gdrive/MyDrive/cluster_faces/Frames/7...  00:02:31  459  211
#
#     FA3  FA4
# 0   278  603
# 1   303  471
# 2   271  799
# 3   331  448
# 4   276  809
# ..  ...  ...
# 70  556  103
# 71  405  216
# 72  401   35
# 73  409  220
# 74  545  141
#
# [75 rows x 8 columns]
# [INFO] processing image 1/75
# [INFO] processing image 2/75
# [INFO] processing image 3/75
# [INFO] processing image 4/75
# [INFO] processing image 5/75
# [INFO] processing image 6/75
# [INFO] processing image 7/75
# [INFO] processing image 8/75
# [INFO] processing image 9/75
# [INFO] processing image 10/75
# [INFO] processing image 11/75
# [INFO] processing image 12/75
# [INFO] processing image 13/75
# [INFO] processing image 14/75
# [INFO] processing image 15/75
# [INFO] processing image 16/75
# [INFO] processing image 17/75
# [INFO] processing image 18/75
# [INFO] processing image 19/75
# [INFO] processing image 20/75
# [INFO] processing image 21/75
# [INFO] processing image 22/75
# [INFO] processing image 23/75
# [INFO] processing image 24/75
# [INFO] processing image 25/75
# [INFO] processing image 26/75
# [INFO] processing image 27/75
# [INFO] processing image 28/75
# [INFO] processing image 29/75
# [INFO] processing image 30/75
# [INFO] processing image 31/75
# [INFO] processing image 32/75
# [INFO] processing image 33/75
# [INFO] processing image 34/75
# [INFO] processing image 35/75
# [INFO] processing image 36/75
# [INFO] processing image 37/75
# [INFO] processing image 38/75
# [INFO] processing image 39/75
# [INFO] processing image 40/75
# [INFO] processing image 41/75
# [INFO] processing image 42/75
# [INFO] processing image 43/75
# [INFO] processing image 44/75
# [INFO] processing image 45/75
# [INFO] processing image 46/75
# [INFO] processing image 47/75
# [INFO] processing image 48/75
# [INFO] processing image 49/75
# [INFO] processing image 50/75
# [INFO] processing image 51/75
# [INFO] processing image 52/75
# [INFO] processing image 53/75
# [INFO] processing image 54/75
# [INFO] processing image 55/75
# [INFO] processing image 56/75
# [INFO] processing image 57/75
# [INFO] processing image 58/75
# [INFO] processing image 59/75
# [INFO] processing image 60/75
# [INFO] processing image 61/75
# [INFO] processing image 62/75
# [INFO] processing image 63/75
# [INFO] processing image 64/75
# [INFO] processing image 65/75
# [INFO] processing image 66/75
# [INFO] processing image 67/75
# [INFO] processing image 68/75
# [INFO] processing image 69/75
# [INFO] processing image 70/75
# [INFO] processing image 71/75
# [INFO] processing image 72/75
# [INFO] processing image 73/75
# [INFO] processing image 74/75
# [INFO] processing image 75/75
# [INFO] serializing encodings...
# /content/gdrive/MyDrive/cluster_faces/pickle_files/77.pickle
# [INFO] loading encodings...
# 75
# [INFO] clustering...
# [INFO] # unique faces: 7
# [INFO] faces for face ID: -1
# [INFO] faces for face ID: 0
# [INFO] faces for face ID: 1
# [INFO] faces for face ID: 2
# [INFO] faces for face ID: 3
# [INFO] faces for face ID: 4
# [INFO] faces for face ID: 5
# [INFO] faces for face ID: 6
#            Character ID Celebrity  \
# 0   Not Clustered Faces   unknown
# 1   Not Clustered Faces   unknown
# 2   Not Clustered Faces   unknown
# 3   Not Clustered Faces   unknown
# 4   Not Clustered Faces   unknown
# ..                  ...       ...
# 70           Face ID #5   unknown
# 71           Face ID #6   unknown
# 72           Face ID #6   unknown
# 73           Face ID #6   unknown
# 74           Face ID #6   unknown
#
#                                             ImagePath  \
# 0   /content/gdrive/MyDrive/cluster_faces/Frames/7...
# 1   /content/gdrive/MyDrive/cluster_faces/Frames/7...
# 2   /content/gdrive/MyDrive/cluster_faces/Frames/7...
# 3   /content/gdrive/MyDrive/cluster_faces/Frames/7...
# 4   /content/gdrive/MyDrive/cluster_faces/Frames/7...
# ..                                                ...
# 70  /content/gdrive/MyDrive/cluster_faces/Frames/7...
# 71  /content/gdrive/MyDrive/cluster_faces/Frames/7...
# 72  /content/gdrive/MyDrive/cluster_faces/Frames/7...
# 73  /content/gdrive/MyDrive/cluster_faces/Frames/7...
# 74  /content/gdrive/MyDrive/cluster_faces/Frames/7...
#
#                                              FacePath TimeStamp
# 0   /content/gdrive/MyDrive/cluster_faces/Faces_Cl...  00:00:46
# 1   /content/gdrive/MyDrive/cluster_faces/Faces_Cl...  00:00:54
# 2   /content/gdrive/MyDrive/cluster_faces/Faces_Cl...  00:02:05
# 3   /content/gdrive/MyDrive/cluster_faces/Faces_Cl...  00:02:13
# 4   /content/gdrive/MyDrive/cluster_faces/Faces_Cl...  00:02:14
# ..                                                ...       ...
# 70  /content/gdrive/MyDrive/cluster_faces/Faces_Cl...  00:02:17
# 71  /content/gdrive/MyDrive/cluster_faces/Faces_Cl...  00:02:14
# 72  /content/gdrive/MyDrive/cluster_faces/Faces_Cl...  00:02:15
# 73  /content/gdrive/MyDrive/cluster_faces/Faces_Cl...  00:02:16
# 74  /content/gdrive/MyDrive/cluster_faces/Faces_Cl...  00:02:17
#
# [75 rows x 5 columns]
# img_000001_0.png => [('a photo of Leonardo DiCaprio', 0.99853515625), ('a photo of others', 0.0009245872497558594), ('a photo of Mark Ruffalo', 0.0005698204040527344)]
# _____________________
# img_000010_0.png => [('a photo of Leonardo DiCaprio', 0.9970703125), ('a photo of others', 0.00225067138671875), ('a photo of Mark Ruffalo', 0.0004162788391113281)]
# _____________________
# img_000010_1.png => [('a photo of Mark Ruffalo', 0.9951171875), ('a photo of Leonardo DiCaprio', 0.002838134765625), ('a photo of others', 0.0010442733764648438)]
# _____________________
# img_000015_0.png => [('a photo of Leonardo DiCaprio', 0.998046875), ('a photo of Mark Ruffalo', 0.0012836456298828125), ('a photo of others', 0.00032973289489746094)]
# _____________________
# img_000028_0.png => [('a photo of Mark Ruffalo', 0.98876953125), ('a photo of Leonardo DiCaprio', 0.01000213623046875), ('a photo of Michelle Williams', 0.000629425048828125)]
# _____________________
# img_000028_1.png => [('a photo of Leonardo DiCaprio', 0.9990234375), ('a photo of Mark Ruffalo', 0.0007791519165039062), ('a photo of others', 0.0003247261047363281)]
# _____________________
# img_000033_0.png => [('a photo of Mark Ruffalo', 0.98876953125), ('a photo of Leonardo DiCaprio', 0.00868988037109375), ('a photo of others', 0.0011396408081054688)]
# _____________________
# img_000035_0.png => [('a photo of Mark Ruffalo', 0.99609375), ('a photo of Leonardo DiCaprio', 0.0025081634521484375), ('a photo of others', 0.0006856918334960938)]
# _____________________
# img_000035_1.png => [('a photo of Leonardo DiCaprio', 0.99853515625), ('a photo of Mark Ruffalo', 0.0007429122924804688), ('a photo of Michelle Williams', 0.0004649162292480469)]
# _____________________
# img_000036_0.png => [('a photo of Mark Ruffalo', 0.99365234375), ('a photo of Leonardo DiCaprio', 0.004673004150390625), ('a photo of others', 0.0008783340454101562)]
# _____________________
# img_000036_1.png => [('a photo of Leonardo DiCaprio', 0.998046875), ('a photo of Mark Ruffalo', 0.0008287429809570312), ('a photo of Michelle Williams', 0.0008158683776855469)]
# _____________________
# img_000040_0.png => [('a photo of Leonardo DiCaprio', 0.99951171875), ('a photo of others', 0.00034046173095703125), ('a photo of Mark Ruffalo', 0.00021648406982421875)]
# _____________________
# img_000040_1.png => [('a photo of Mark Ruffalo', 0.99951171875), ('a photo of Leonardo DiCaprio', 0.0003249645233154297), ('a photo of others', 0.0001766681671142578)]
# _____________________
# img_000041_0.png => [('a photo of Leonardo DiCaprio', 0.99853515625), ('a photo of Mark Ruffalo', 0.0006766319274902344), ('a photo of others', 0.0006556510925292969)]
# _____________________
# img_000041_1.png => [('a photo of Mark Ruffalo', 1.0), ('a photo of others', 0.00010228157043457031), ('a photo of Leonardo DiCaprio', 9.608268737792969e-05)]
# _____________________
# img_000044_0.png => [('a photo of Ben Kingsley', 1.0), ('a photo of Emily Mortimer', 1.3232231140136719e-05), ('a photo of others', 1.0788440704345703e-05)]
# _____________________
# img_000045_0.png => [('a photo of Ben Kingsley', 1.0), ('a photo of others', 6.109476089477539e-05), ('a photo of Max von Sydow', 2.7954578399658203e-05)]
# _____________________
# img_000046_0.png => [('a photo of Ben Kingsley', 1.0), ('a photo of others', 2.8431415557861328e-05), ('a photo of Patricia Clarkson', 5.602836608886719e-06)]
# _____________________
# img_000053_0.png => [('a photo of Max von Sydow', 0.99169921875), ('a photo of Michelle Williams', 0.007114410400390625), ('a photo of others', 0.0006513595581054688)]
# _____________________
# img_000054_0.png => [('a photo of Max von Sydow', 0.344970703125), ('a photo of Ben Kingsley', 0.3291015625), ('a photo of Michelle Williams', 0.1734619140625)]
# _____________________
# img_000054_1.png => [('a photo of Max von Sydow', 0.9970703125), ('a photo of Michelle Williams', 0.0025501251220703125), ('a photo of others', 0.00040340423583984375)]
# _____________________
# img_000055_0.png => [('a photo of Max von Sydow', 0.99169921875), ('a photo of Michelle Williams', 0.0070037841796875), ('a photo of others', 0.0007266998291015625)]
# _____________________
# img_000056_0.png => [('a photo of Max von Sydow', 0.998046875), ('a photo of Michelle Williams', 0.0013246536254882812), ('a photo of others', 0.0003914833068847656)]
# _____________________
# img_000058_0.png => [('a photo of Leonardo DiCaprio', 0.998046875), ('a photo of Mark Ruffalo', 0.0014772415161132812), ('a photo of others', 0.00031948089599609375)]
# _____________________
# img_000059_0.png => [('a photo of Leonardo DiCaprio', 0.99951171875), ('a photo of Mark Ruffalo', 0.00033020973205566406), ('a photo of others', 6.705522537231445e-05)]
# _____________________
# img_000060_0.png => [('a photo of Leonardo DiCaprio', 0.998046875), ('a photo of others', 0.001224517822265625), ('a photo of Michelle Williams', 0.0004367828369140625)]
# _____________________
# img_000071_0.png => [('a photo of Leonardo DiCaprio', 0.99951171875), ('a photo of others', 0.00028228759765625), ('a photo of Mark Ruffalo', 0.0001659393310546875)]
# _____________________
# img_000104_0.png => [('a photo of Leonardo DiCaprio', 0.982421875), ('a photo of Mark Ruffalo', 0.01491546630859375), ('a photo of others', 0.0025920867919921875)]
# _____________________
# img_000105_0.png => [('a photo of Leonardo DiCaprio', 0.99658203125), ('a photo of Mark Ruffalo', 0.00279998779296875), ('a photo of others', 0.00036144256591796875)]
# _____________________
# img_000106_0.png => [('a photo of Leonardo DiCaprio', 0.99169921875), ('a photo of Mark Ruffalo', 0.00745391845703125), ('a photo of others', 0.0007152557373046875)]
# _____________________
# img_000107_0.png => [('a photo of Leonardo DiCaprio', 0.990234375), ('a photo of Mark Ruffalo', 0.0048065185546875), ('a photo of others', 0.00458526611328125)]
# _____________________
# img_000121_0.png => [('a photo of Ben Kingsley', 1.0), ('a photo of Emily Mortimer', 6.604194641113281e-05), ('a photo of Patricia Clarkson', 4.684925079345703e-05)]
# _____________________
# img_000122_0.png => [('a photo of Ben Kingsley', 1.0), ('a photo of Patricia Clarkson', 3.5881996154785156e-05), ('a photo of others', 2.282857894897461e-05)]
# _____________________
# img_000123_0.png => [('a photo of Leonardo DiCaprio', 1.0), ('a photo of others', 9.316205978393555e-05), ('a photo of Mark Ruffalo', 3.272294998168945e-05)]
# _____________________
# img_000124_0.png => [('a photo of Leonardo DiCaprio', 0.9912109375), ('a photo of others', 0.006999969482421875), ('a photo of Mark Ruffalo', 0.0017423629760742188)]
# _____________________
# img_000125_0.png => [('a photo of Mark Ruffalo', 0.5908203125), ('a photo of Ben Kingsley', 0.114501953125), ('a photo of Emily Mortimer', 0.096435546875)]
# _____________________
# img_000132_0.png => [('a photo of Leonardo DiCaprio', 0.266357421875), ('a photo of others', 0.2242431640625), ('a photo of Mark Ruffalo', 0.1978759765625)]
# _____________________
# img_000132_1.png => [('a photo of Emily Mortimer', 0.9892578125), ('a photo of Michelle Williams', 0.00543975830078125), ('a photo of Mark Ruffalo', 0.0016088485717773438)]
# _____________________
# img_000132_2.png => [('a photo of Leonardo DiCaprio', 0.395263671875), ('a photo of Max von Sydow', 0.208251953125), ('a photo of others', 0.192626953125)]
# _____________________
# img_000132_3.png => [('a photo of Leonardo DiCaprio', 0.94287109375), ('a photo of Emily Mortimer', 0.0236053466796875), ('a photo of others', 0.01064300537109375)]
# _____________________
# img_000133_0.png => [('a photo of Emily Mortimer', 0.9921875), ('a photo of Michelle Williams', 0.002742767333984375), ('a photo of Mark Ruffalo', 0.0017442703247070312)]
# _____________________
# img_000133_1.png => [('a photo of Leonardo DiCaprio', 0.67138671875), ('a photo of Michelle Williams', 0.1923828125), ('a photo of others', 0.06646728515625)]
# _____________________
# img_000133_2.png => [('a photo of Leonardo DiCaprio', 0.552734375), ('a photo of others', 0.1851806640625), ('a photo of Michelle Williams', 0.10882568359375)]
# _____________________
# img_000133_3.png => [('a photo of Leonardo DiCaprio', 0.410400390625), ('a photo of Mark Ruffalo', 0.30029296875), ('a photo of others', 0.260986328125)]
# _____________________
# img_000133_4.png => [('a photo of Leonardo DiCaprio', 0.89892578125), ('a photo of others', 0.046173095703125), ('a photo of Michelle Williams', 0.02215576171875)]
# _____________________
# img_000133_5.png => [('a photo of Leonardo DiCaprio', 0.89599609375), ('a photo of Mark Ruffalo', 0.06097412109375), ('a photo of Michelle Williams', 0.03265380859375)]
# _____________________
# img_000134_0.png => [('a photo of Michelle Williams', 0.94921875), ('a photo of Patricia Clarkson', 0.02490234375), ('a photo of Mark Ruffalo', 0.01140594482421875)]
# _____________________
# img_000134_1.png => [('a photo of Emily Mortimer', 0.990234375), ('a photo of Michelle Williams', 0.0049591064453125), ('a photo of Mark Ruffalo', 0.0016613006591796875)]
# _____________________
# img_000134_2.png => [('a photo of others', 0.330322265625), ('a photo of Leonardo DiCaprio', 0.296142578125), ('a photo of Michelle Williams', 0.1634521484375)]
# _____________________
# img_000134_3.png => [('a photo of Leonardo DiCaprio', 0.55517578125), ('a photo of others', 0.393798828125), ('a photo of Mark Ruffalo', 0.03607177734375)]
# _____________________
# img_000135_0.png => [('a photo of Michelle Williams', 0.9794921875), ('a photo of Emily Mortimer', 0.006103515625), ('a photo of Mark Ruffalo', 0.0053863525390625)]
# _____________________
# img_000135_1.png => [('a photo of Leonardo DiCaprio', 0.919921875), ('a photo of Mark Ruffalo', 0.07550048828125), ('a photo of others', 0.0034770965576171875)]
# _____________________
# img_000135_2.png => [('a photo of Leonardo DiCaprio', 0.8232421875), ('a photo of Mark Ruffalo', 0.10467529296875), ('a photo of others', 0.042266845703125)]
# _____________________
# img_000135_3.png => [('a photo of others', 0.312255859375), ('a photo of Leonardo DiCaprio', 0.2978515625), ('a photo of Michelle Williams', 0.159423828125)]
# _____________________
# img_000135_4.png => [('a photo of Mark Ruffalo', 0.49609375), ('a photo of Leonardo DiCaprio', 0.28271484375), ('a photo of others', 0.1466064453125)]
# _____________________
# img_000135_5.png => [('a photo of Patricia Clarkson', 0.82861328125), ('a photo of Michelle Williams', 0.11749267578125), ('a photo of others', 0.0270538330078125)]
# _____________________
# img_000136_0.png => [('a photo of Michelle Williams', 0.97216796875), ('a photo of Patricia Clarkson', 0.01453399658203125), ('a photo of Emily Mortimer', 0.01030731201171875)]
# _____________________
# img_000136_1.png => [('a photo of Leonardo DiCaprio', 0.99658203125), ('a photo of others', 0.001148223876953125), ('a photo of Max von Sydow', 0.0010137557983398438)]
# _____________________
# img_000136_2.png => [('a photo of others', 0.31494140625), ('a photo of Leonardo DiCaprio', 0.300537109375), ('a photo of Michelle Williams', 0.1558837890625)]
# _____________________
# img_000136_3.png => [('a photo of Mark Ruffalo', 0.361328125), ('a photo of Leonardo DiCaprio', 0.285888671875), ('a photo of others', 0.25634765625)]
# _____________________
# img_000136_4.png => [('a photo of Patricia Clarkson', 0.56884765625), ('a photo of Michelle Williams', 0.29052734375), ('a photo of Leonardo DiCaprio', 0.10040283203125)]
# _____________________
# img_000137_0.png => [('a photo of Michelle Williams', 0.96533203125), ('a photo of Emily Mortimer', 0.016876220703125), ('a photo of Patricia Clarkson', 0.0115966796875)]
# _____________________
# img_000137_1.png => [('a photo of others', 0.322998046875), ('a photo of Leonardo DiCaprio', 0.308349609375), ('a photo of Michelle Williams', 0.1650390625)]
# _____________________
# img_000137_2.png => [('a photo of Emily Mortimer', 0.99658203125), ('a photo of Michelle Williams', 0.0025482177734375), ('a photo of Patricia Clarkson', 0.0005426406860351562)]
# _____________________
# img_000137_3.png => [('a photo of Max von Sydow', 0.85791015625), ('a photo of others', 0.053985595703125), ('a photo of Michelle Williams', 0.03485107421875)]
# _____________________
# img_000139_0.png => [('a photo of Leonardo DiCaprio', 0.48876953125), ('a photo of Emily Mortimer', 0.257568359375), ('a photo of Mark Ruffalo', 0.1611328125)]
# _____________________
# img_000140_0.png => [('a photo of Ben Kingsley', 0.98974609375), ('a photo of Emily Mortimer', 0.0051116943359375), ('a photo of others', 0.0023784637451171875)]
# _____________________
# img_000141_0.png => [('a photo of Ben Kingsley', 0.994140625), ('a photo of Emily Mortimer', 0.003421783447265625), ('a photo of others', 0.001163482666015625)]
# _____________________
# img_000142_0.png => [('a photo of Emily Mortimer', 0.6552734375), ('a photo of Michelle Williams', 0.1656494140625), ('a photo of Leonardo DiCaprio', 0.1417236328125)]
# _____________________
# img_000142_1.png => [('a photo of Emily Mortimer', 0.82470703125), ('a photo of Leonardo DiCaprio', 0.1207275390625), ('a photo of others', 0.0277862548828125)]
# _____________________
# img_000144_0.png => [('a photo of Max von Sydow', 0.97802734375), ('a photo of others', 0.011932373046875), ('a photo of Michelle Williams', 0.006801605224609375)]
# _____________________
# img_000145_0.png => [('a photo of Mark Ruffalo', 0.4267578125), ('a photo of others', 0.312255859375), ('a photo of Ben Kingsley', 0.1806640625)]
# _____________________
# img_000146_0.png => [('a photo of Michelle Williams', 0.54296875), ('a photo of Emily Mortimer', 0.226318359375), ('a photo of others', 0.2060546875)]
# _____________________
# img_000146_1.png => [('a photo of Mark Ruffalo', 0.37109375), ('a photo of others', 0.298095703125), ('a photo of Ben Kingsley', 0.29345703125)]
# _____________________
# img_000151_0.png => [('a photo of Michelle Williams', 0.399658203125), ('a photo of Patricia Clarkson', 0.29248046875), ('a photo of Mark Ruffalo', 0.144775390625)]
# _____________________

# %%
obj = CID()
celebrity_list = ["Robert Downey Jr.", "Chris Evans", "Mark Ruffalo", "Chris Hemsworth", "Scarlett Johansson","Jeremy Renner",
                  "Tom Hiddleston","Clark Gregg","Cobie Smulders","Stellan Skarsgård",
                    "Samuel L. Jackson"]

obj.start_process(78, celebrity_list, "/content/gdrive/MyDrive/cluster_faces/avengers.mp4")
