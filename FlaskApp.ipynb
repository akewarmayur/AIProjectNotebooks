# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !pip install flask_ngrok

# %%
# !pip install pyngrok==4.1.1

# %%
# !ngrok authtoken "2RplDDVGfPC6QLaUAHTNpgEtxPE_3emoV7KiK25FSXA9suDPp"
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
# !python "/content/gdrive/My Drive/App/main2.py"
# Out:
#  * Serving Flask app 'main2'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Running on http://b800-34-125-93-15.ngrok-free.app
#  * Traffic stats available on http://127.0.0.1:4040
# 127.0.0.1 - - [28/Jun/2023 12:22:13] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2023 12:22:13] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2023 12:22:13] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [28/Jun/2023 12:22:41] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2023 12:22:42] "GET /static/uploads/test_videoimg_000047.png HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2023 12:22:42] "GET /static/uploads/TheIrishmanimg_000004.png HTTP/1.1" 200 -
# 127.0.0.1 - - [28/Jun/2023 12:22:42] "GET /static/uploads/TheIrishmanimg_000003.png HTTP/1.1" 200 -
# ...
