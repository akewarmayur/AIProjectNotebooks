# %%
# !git clone https://github.com/Stability-AI/generative-models.git
# Out:
# Cloning into 'generative-models'...
# remote: Enumerating objects: 169, done.
# remote: Counting objects: 100% (65/65), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 169 (delta 40), reused 25 (delta 25), pack-reused 104
# Receiving objects: 100% (169/169), 18.21 MiB | 16.98 MiB/s, done.
# Resolving deltas: 100% (66/66), done.

# %%
cd generative-models
# Out:
# /content/generative-models

# %%
# !pip install -r requirements_pt13.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu117
# Obtaining taming-transformers from git+https://github.com/CompVis/taming-transformers.git@master#egg=taming-transformers (from -r requirements_pt13.txt (line 38))
#   Updating ./src/taming-transformers clone (to revision master)
#   Running command git fetch -q --tags
#   Running command git reset --hard -q 3ba01b241669f5ade541ce990f7650a3b8f65318
#   Preparing metadata (setup.py) ... done
# Obtaining clip from git+https://github.com/openai/CLIP.git@main#egg=clip (from -r requirements_pt13.txt (line 39))
#   Updating ./src/clip clone (to revision main)
#   Running command git fetch -q --tags
#   Running command git reset --hard -q a1d071733d7111c9c014f024669f959182114e33
#   Preparing metadata (setup.py) ... done
# Obtaining sdata from git+https://github.com/Stability-AI/datapipelines.git@main#egg=sdata (from -r requirements_pt13.txt (line 40))
#   Updating ./src/sdata clone (to revision main)
# ...

# %%
# !streamlit run scripts/demo/sampling.py --server.port 8000
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8000
#   External URL: http://34.143.136.16:8000
#
#   Stopping...
#   Stopping...
