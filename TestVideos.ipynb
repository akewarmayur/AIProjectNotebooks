# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %%capture
# !conda install --yes -c pytorch pytorch=1.7.1 torchvision cudatoolkit=11.0
# !pip install ftfy regex tqdm
# !pip install git+https://github.com/openai/CLIP.git

# %%
# !ls
# Out:
# finalPrompts777.py  gdrive  sample_data

# %%
# !python finalPrompts777.py
# Out:
# vi_ph_bu_dead_body_2_vOY0DGbgFlg_302_312
# img_000001 : [('image showing a injured person with significant blood loss and clothes are covered with blood', 0.0826416015625), ('image showing a injured person among the lifeless human bodies', 0.06640625), ('image showing a mutilated bloody body of a person', 0.06439208984375)]
# violence
# ___________________________
# img_000002 : [('image showing a injured person with significant blood loss and clothes are covered with blood', 0.0826416015625), ('image showing a injured person among the lifeless human bodies', 0.06640625), ('image showing a mutilated bloody body of a person', 0.06439208984375)]
# violence
# ___________________________
# img_000003 : [('image showing a injured person with significant blood loss and clothes are covered with blood', 0.0826416015625), ('image showing a injured person among the lifeless human bodies', 0.06640625), ('image showing a mutilated bloody body of a person', 0.06439208984375)]
# violence
# ___________________________
# img_000004 : [('image showing a injured person with significant blood loss and clothes are covered with blood', 0.0826416015625), ('image showing a injured person among the lifeless human bodies', 0.06640625), ('image showing a mutilated bloody body of a person', 0.06439208984375)]
# violence
# ___________________________
# img_000005 : [('image showing a injured person among the lifeless human bodies', 0.10260009765625), ('image showing a injured person with significant blood loss and clothes are covered with blood', 0.09637451171875), ('image showing a mutilated body of a person', 0.08642578125)]
# violence
# ___________________________
# img_000006 : [('image showing a mutilated bloody body of a person', 0.14306640625), ('image showing a dead body or corpse with blood', 0.13232421875), ('image showing a mutilated body of a person', 0.09527587890625)]
# violence
# ___________________________
# img_000007 : [('image showing a dead body or corpse with blood', 0.1627197265625), ('image showing a mutilated bloody body of a person', 0.1392822265625), ('image showing a person holding a dead body or a corpse with blood', 0.0987548828125)]
# violence
# ___________________________
# img_000008 : [('image showing a dead body or corpse with blood', 0.1787109375), ('image showing a mutilated bloody body of a person', 0.1505126953125), ('image showing a dead mutilated corpse', 0.0733642578125)]
# violence
# ___________________________
# img_000009 : [('image showing any bloodstains or lots of blood on the ground or other surfaces', 0.38525390625), ('image showing many dead bodies on the ground after a brutal fight', 0.216064453125), ('image showing a brutal fight with blood shed', 0.06591796875)]
# violence
# ___________________________
# img_000010 : [('image showing any bloodstains or lots of blood on the ground or other surfaces', 0.45849609375), ('image showing many dead bodies on the ground after a brutal fight', 0.1971435546875), ('image showing a brutal fight with blood shed', 0.0592041015625)]
# violence
# ___________________________
